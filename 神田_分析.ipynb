# %% [markdown]
# # 分析のロードマップ
# ### 大枠
# - 千代田区とその他の22区の比較
# - 千代田区と開発区域の比較
# #### 比較項目
# - 人口ピラミッド←POP
# - 世帯類型←GENHHFANUM_H27

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.0-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
base=gpd.read_file('./01_proccessing/神田再開発地区_小地域.geojson')
job=gpd.read_file('./00_data/3_関東/json/CHO_JOB_H27.geojson')
pop=gpd.read_file('./00_data/3_関東/json/CHO_POP_H27.geojson')
mob=gpd.read_file('./00_data/3_関東/json/CHO_MOB_H27.geojson')

# %%
base
# Out:
#        KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME    S_NAME KIGO_E  HCODE  \
# 0   13101020002   13  101  020002       東京都      千代田区    一ツ橋２丁目   None   8101
# 1   13101021001   13  101  021001       東京都      千代田区  神田神保町１丁目   None   8101
# 2   13101021002   13  101  021002       東京都      千代田区  神田神保町２丁目   None   8101
# 3   13101021003   13  101  021003       東京都      千代田区  神田神保町３丁目   None   8101
# 4   13101026001   13  101  026001       東京都      千代田区   神田錦町１丁目   None   8101
# 5   13101026002   13  101  026002       東京都      千代田区   神田錦町２丁目   None   8101
# 6   13101026003   13  101  026003       東京都      千代田区   神田錦町３丁目   None   8101
# 7   13101027001   13  101  027001       東京都      千代田区  神田小川町１丁目   None   8101
# 8   13101027002   13  101  027002       東京都      千代田区  神田小川町２丁目   None   8101
# 9   13101027003   13  101  027003       東京都      千代田区  神田小川町３丁目   None   8101
# 10    131010280   13  101  028000       東京都      千代田区    神田美土代町   None   8101
# ...

# %%
df=pd.merge(base,pop,on="KEY_CODE",)
df
# Out:
#        KEY_CODE PREF CITY_x  S_AREA PREF_NAME CITY_NAME    S_NAME KIGO_E  \
# 0   13101020002   13    101  020002       東京都      千代田区    一ツ橋２丁目   None
# 1   13101021001   13    101  021001       東京都      千代田区  神田神保町１丁目   None
# 2   13101021002   13    101  021002       東京都      千代田区  神田神保町２丁目   None
# 3   13101021003   13    101  021003       東京都      千代田区  神田神保町３丁目   None
# 4   13101026001   13    101  026001       東京都      千代田区   神田錦町１丁目   None
# 5   13101026002   13    101  026002       東京都      千代田区   神田錦町２丁目   None
# 6   13101026003   13    101  026003       東京都      千代田区   神田錦町３丁目   None
# 7   13101027001   13    101  027001       東京都      千代田区  神田小川町１丁目   None
# 8   13101027002   13    101  027002       東京都      千代田区  神田小川町２丁目   None
# 9   13101027003   13    101  027003       東京都      千代田区  神田小川町３丁目   None
# 10    131010280   13    101  028000       東京都      千代田区    神田美土代町   None
# 11  13101029001   13    101  029001       東京都      千代田区    内神田１丁目   None
# ...

# %%
df.columns.values
# Out:
# array(['KEY_CODE', 'PREF', 'CITY_x', 'S_AREA', 'PREF_NAME', 'CITY_NAME',
#        'S_NAME', 'KIGO_E', 'HCODE', 'AREA', 'PERIMETER', 'H27KAxx_',
#        'H27KAxx_ID', 'KEN_x', 'KEN_NAME_x', 'SITYO_NAME', 'GST_NAME',
#        'CSS_NAME', 'KIHON1_x', 'DUMMY1', 'KIHON2_x', 'KEYCODE1',
#        'KEYCODE2', 'AREA_MAX_F', 'KIGO_D', 'N_KEN', 'N_CITY', 'KIGO_I',
#        'MOJI', 'KBSUM', 'JINKO', 'SETAI', 'X_CODE', 'Y_CODE', 'KCODE1',
#        'geometry_x', 'OBJECTID', 'KEN_y', 'CITY_y', 'KIHON1_y',
#        'KIHON2_y', 'SIKINUM', 'HTKSYU', 'SYUROKU', 'HITOKU_CODE',
#        'GASS_1', 'GASS_2', 'GASS_3', 'GASS_4', 'GASS_5', 'GASS_6',
#        'GASS_7', 'GASS_8', 'KEN_NAME_y', 'SHICHO_NAME', 'SHI_NAME',
#        'KU_NAME', 'GUN_NAME', 'CHOSON_NAME', 'OAZA_NAME', 'KOAZA_NAME',
#        'SUM_AREA', 'ID', 'NAME', 'TOTPOP_H27', 'TOTMALE_H27',
#        'TOTFEMALE_H27', 'TOTHH_H27', 'TOTPOP_INC_H27', 'POP_0_4_H27',
#        'POP_5_9_H27', 'POP_10_14_H27', 'POP_15_19_H27', 'POP_20_24_H27',
# ...
